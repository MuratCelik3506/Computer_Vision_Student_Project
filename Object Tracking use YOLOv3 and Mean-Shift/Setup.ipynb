# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
try :
  os.chdir("drive/My Drive")
  os.chdir("BBM418/Assignment 4")
  os.chdir("Part 2")
except: 
  print("Already set")

# %%
os.listdir()
# Out:
# ['yolov3.weights', 'yolov3.cfg', 'Yolo.ipynb', 'vot2017.zip', 'Setup.ipynb']

# %% [markdown]
# ## Download Dataset

# %%
# !unzip vot2017.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/vot2017/car1/color/00000277.jpg
#   inflating: content/vot2017/car1/color/00000670.jpg
#   inflating: content/vot2017/car1/color/00000258.jpg
#   inflating: content/vot2017/car1/color/00000106.jpg
#   inflating: content/vot2017/car1/color/00000123.jpg
#   inflating: content/vot2017/car1/color/00000675.jpg
#   inflating: content/vot2017/car1/color/00000604.jpg
#   inflating: content/vot2017/car1/color/00000637.jpg
#   inflating: content/vot2017/car1/color/00000175.jpg
#   inflating: content/vot2017/car1/color/00000721.jpg
#   inflating: content/vot2017/car1/color/00000598.jpg
#   inflating: content/vot2017/car1/color/00000260.jpg
#   inflating: content/vot2017/car1/color/00000435.jpg
#   inflating: content/vot2017/car1/color/00000207.jpg
#   inflating: content/vot2017/car1/color/00000051.jpg
#   inflating: content/vot2017/car1/color/00000669.jpg
#   inflating: content/vot2017/car1/color/00000148.jpg
# ...

# %% [markdown]
# A[## Get yolov3 weight on internet

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2022-05-23 07:46:20--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  19.4MB/s    in 13s
#
# 2022-05-23 07:46:34 (17.8 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
import os
os.listdir()
# Out:
# ['vot2017.zip',
#  'Setup.ipynb',
#  'content',
#  'yolov3.cfg',
#  'yolov3.weights',
#  'Yolo.ipynb']

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/BBM418/Assignment 4/Part 2'
